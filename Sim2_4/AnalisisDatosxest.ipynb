# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def GM(dim , ensamble, shots):
    return (dim-1)/(shots*ensamble+1)

# %% [markdown]
# ### 1. Cargar datos
#
# Cada archivo de datos es una matriz de 100x10, 100 estados random de dimensión d y 10 estimaciones de cada estado.

# %%
# Dimension 4, todos los ensambles

d4n5_Fid1 = np.loadtxt('dim=4,ens=10^5,fids_1.txt')
d4n5_Fid2 = np.loadtxt('dim=4,ens=10^5,fids_2.txt')
d4n55_Fid1 = np.loadtxt('dim=4,ens=10^55,fids_1.txt')
d4n55_Fid2 = np.loadtxt('dim=4,ens=10^55,fids_2.txt')
d4n6_Fid1 = np.loadtxt('dim=4,ens=10^6,fids_1.txt')
d4n6_Fid2 = np.loadtxt('dim=4,ens=10^6,fids_2.txt')
d4n65_Fid1 = np.loadtxt('dim=4,ens=10^65,fids_1.txt')
d4n65_Fid2 = np.loadtxt('dim=4,ens=10^65,fids_2.txt')
d4n7_Fid1 = np.loadtxt('dim=4,ens=10^7,fids_1.txt')
d4n7_Fid2 = np.loadtxt('dim=4,ens=10^7,fids_2.txt')

# %%
# Dimension 8, todos los ensambles

d8n5_Fid1 = np.loadtxt('dim=8,ens=10^5,fids_1.txt')
d8n5_Fid2 = np.loadtxt('dim=8,ens=10^5,fids_2.txt')
d8n55_Fid1 = np.loadtxt('dim=8,ens=10^55,fids_1.txt')
d8n55_Fid2 = np.loadtxt('dim=8,ens=10^55,fids_2.txt')
d8n6_Fid1 = np.loadtxt('dim=8,ens=10^6,fids_1.txt')
d8n6_Fid2 = np.loadtxt('dim=8,ens=10^6,fids_2.txt')
d8n65_Fid1 = np.loadtxt('dim=8,ens=10^65,fids_1.txt')
d8n65_Fid2 = np.loadtxt('dim=8,ens=10^65,fids_2.txt')
d8n7_Fid1 = np.loadtxt('dim=8,ens=10^7,fids_1.txt')
d8n7_Fid2 = np.loadtxt('dim=8,ens=10^7,fids_2.txt')

# %%
# Dimension 16, todos los ensambles

d16n5_Fid1 = np.loadtxt('dim=16,ens=10^5,fids_1.txt')
d16n5_Fid2 = np.loadtxt('dim=16,ens=10^5,fids_2.txt')
d16n55_Fid1 = np.loadtxt('dim=16,ens=10^55,fids_1.txt')
d16n55_Fid2 = np.loadtxt('dim=16,ens=10^55,fids_2.txt')
d16n6_Fid1 = np.loadtxt('dim=16,ens=10^6,fids_1.txt')
d16n6_Fid2 = np.loadtxt('dim=16,ens=10^6,fids_2.txt')
d16n65_Fid1 = np.loadtxt('dim=16,ens=10^65,fids_1.txt')
d16n65_Fid2 = np.loadtxt('dim=16,ens=10^65,fids_2.txt')
d16n7_Fid1 = np.loadtxt('dim=16,ens=10^7,fids_1.txt')
d16n7_Fid2 = np.loadtxt('dim=16,ens=10^7,fids_2.txt')

# %%
# Dimension 32, todos los ensambles

d32n5_Fid1 = np.loadtxt('dim=32,ens=10^5,fids_1.txt')
d32n5_Fid2 = np.loadtxt('dim=32,ens=10^5,fids_2.txt')
d32n55_Fid1 = np.loadtxt('dim=32,ens=10^55,fids_1.txt')
d32n55_Fid2 = np.loadtxt('dim=32,ens=10^55,fids_2.txt')
d32n6_Fid1 = np.loadtxt('dim=32,ens=10^6,fids_1.txt')
d32n6_Fid2 = np.loadtxt('dim=32,ens=10^6,fids_2.txt')
d32n65_Fid1 = np.loadtxt('dim=32,ens=10^65,fids_1.txt')
d32n65_Fid2 = np.loadtxt('dim=32,ens=10^65,fids_2.txt')
d32n7_Fid1 = np.loadtxt('dim=32,ens=10^7,fids_1.txt')
d32n7_Fid2 = np.loadtxt('dim=32,ens=10^7,fids_2.txt')

# %%
# Dimension 64, todos los ensambles

d64n5_Fid1 = np.loadtxt('dim=64,ens=10^5,fids_1.txt')
d64n5_Fid2 = np.loadtxt('dim=64,ens=10^5,fids_2.txt')
d64n55_Fid1 = np.loadtxt('dim=64,ens=10^55,fids_1.txt')
d64n55_Fid2 = np.loadtxt('dim=64,ens=10^55,fids_2.txt')
d64n6_Fid1 = np.loadtxt('dim=64,ens=10^6,fids_1.txt')
d64n6_Fid2 = np.loadtxt('dim=64,ens=10^6,fids_2.txt')
d64n65_Fid1 = np.loadtxt('dim=64,ens=10^65,fids_1.txt')
d64n65_Fid2 = np.loadtxt('dim=64,ens=10^65,fids_2.txt')
d64n7_Fid1 = np.loadtxt('dim=64,ens=10^7,fids_1.txt')
d64n7_Fid2 = np.loadtxt('dim=64,ens=10^7,fids_2.txt')

# %% [markdown]
# ### 2. Crear vectores de datos
# Graficar Infidelidad en estimaciones para un estado dado , ensamble vs Infidelidad y Dimension vs Infidelidad

# %%
## Infidelidad vs Dimensión para distintos Ensambles

# Media de la fidelidad para 10 estimaciones de 1 estado random para cada dimension y ensamble

meanfid1_n5 = np.array( [np.mean(d4n5_Fid1, axis=1),np.mean(d8n5_Fid1, axis=1), np.mean(d16n5_Fid1, axis=1), np.mean(d32n5_Fid1, axis=1),np.mean(d64n5_Fid1, axis=1)])
meanfid2_n5 = np.array( [np.mean(d4n5_Fid2, axis=1),np.mean(d8n5_Fid2, axis=1), np.mean(d16n5_Fid2, axis=1), np.mean(d32n5_Fid2, axis=1),np.mean(d64n5_Fid2, axis=1)])

meanfid1_n55 = np.array( [np.mean(d4n55_Fid1, axis=1),np.mean(d8n55_Fid1, axis=1), np.mean(d16n55_Fid1, axis=1), np.mean(d32n55_Fid1, axis=1),np.mean(d64n55_Fid1, axis=1)])
meanfid2_n55 = np.array( [np.mean(d4n55_Fid2, axis=1),np.mean(d8n55_Fid2, axis=1), np.mean(d16n55_Fid2, axis=1), np.mean(d32n55_Fid2, axis=1),np.mean(d64n55_Fid2, axis=1)])

meanfid1_n6 = np.array( [np.mean(d4n6_Fid1, axis=1),np.mean(d8n6_Fid1, axis=1), np.mean(d16n6_Fid1, axis=1), np.mean(d32n6_Fid1, axis=1),np.mean(d64n6_Fid1, axis=1)])
meanfid2_n6 = np.array( [np.mean(d4n6_Fid2, axis=1),np.mean(d8n6_Fid2, axis=1), np.mean(d16n6_Fid2, axis=1), np.mean(d32n6_Fid2, axis=1),np.mean(d64n6_Fid2, axis=1)])

meanfid1_n65 = np.array( [np.mean(d4n65_Fid1, axis=1),np.mean(d8n65_Fid1, axis=1), np.mean(d16n65_Fid1, axis=1), np.mean(d32n65_Fid1, axis=1),np.mean(d64n65_Fid1, axis=1)])
meanfid2_n65 = np.array( [np.mean(d4n65_Fid2, axis=1),np.mean(d8n65_Fid2, axis=1), np.mean(d16n65_Fid2, axis=1), np.mean(d32n65_Fid2, axis=1),np.mean(d64n65_Fid2, axis=1)])

meanfid1_n7 = np.array( [np.mean(d4n7_Fid1, axis=1),np.mean(d8n7_Fid1, axis=1), np.mean(d16n7_Fid1, axis=1), np.mean(d32n7_Fid1, axis=1),np.mean(d64n7_Fid1, axis=1)])
meanfid2_n7 = np.array( [np.mean(d4n7_Fid2, axis=1),np.mean(d8n7_Fid2, axis=1), np.mean(d16n7_Fid2, axis=1), np.mean(d32n7_Fid2, axis=1),np.mean(d64n7_Fid2, axis=1)])

# Desviación estándar de las fidelidades de las 10 estimaciones de cada estado random por dimension y ensamble

stdfid1_n5 = np.array( [np.std(d4n5_Fid1, axis=1),np.std(d8n5_Fid1, axis=1), np.std(d16n5_Fid1, axis=1), np.std(d32n5_Fid1, axis=1),np.std(d64n5_Fid1, axis=1)])
stdfid2_n5 = np.array( [np.std(d4n5_Fid2, axis=1),np.std(d8n5_Fid2, axis=1), np.std(d16n5_Fid2, axis=1), np.std(d32n5_Fid2, axis=1),np.std(d64n5_Fid2, axis=1)])

stdfid1_n55 = np.array( [np.std(d4n55_Fid1, axis=1),np.std(d8n55_Fid1, axis=1), np.std(d16n55_Fid1, axis=1), np.std(d32n55_Fid1, axis=1),np.std(d64n55_Fid1, axis=1)])
stdfid2_n55 = np.array( [np.std(d4n55_Fid2, axis=1),np.std(d8n55_Fid2, axis=1), np.std(d16n55_Fid2, axis=1), np.std(d32n55_Fid2, axis=1),np.std(d64n55_Fid2, axis=1)])

stdfid1_n6 = np.array( [np.std(d4n6_Fid1, axis=1),np.std(d8n6_Fid1, axis=1), np.std(d16n6_Fid1, axis=1), np.std(d32n6_Fid1, axis=1),np.std(d64n6_Fid1, axis=1)])
stdfid2_n6 = np.array( [np.std(d4n6_Fid2, axis=1),np.std(d8n6_Fid2, axis=1), np.std(d16n6_Fid2, axis=1), np.std(d32n6_Fid2, axis=1),np.std(d64n6_Fid2, axis=1)])

stdfid1_n65 = np.array( [np.std(d4n65_Fid1, axis=1),np.std(d8n65_Fid1, axis=1), np.std(d16n65_Fid1, axis=1), np.std(d32n65_Fid1, axis=1),np.std(d64n65_Fid1, axis=1)])
stdfid2_n65 = np.array( [np.std(d4n65_Fid2, axis=1),np.std(d8n65_Fid2, axis=1), np.std(d16n65_Fid2, axis=1), np.std(d32n65_Fid2, axis=1),np.std(d64n65_Fid2, axis=1)])

stdfid1_n7 = np.array( [np.std(d4n7_Fid1, axis=1),np.std(d8n7_Fid1, axis=1), np.std(d16n7_Fid1, axis=1), np.std(d32n7_Fid1, axis=1),np.std(d64n7_Fid1, axis=1)])
stdfid2_n7 = np.array( [np.std(d4n7_Fid2, axis=1),np.std(d8n7_Fid2, axis=1), np.std(d16n7_Fid2, axis=1), np.std(d32n7_Fid2, axis=1),np.std(d64n7_Fid2, axis=1)])

## Infidelidad vs Ensamble para distintas dimensiones

# Media de la fidelidad para 10 estimaciones de 1 estado random para cada dimension y ensamble


meanfid1_d4 = np.array( [np.mean(d4n5_Fid1, axis=1),np.mean(d4n55_Fid1, axis=1),np.mean(d4n6_Fid1, axis=1),np.mean(d4n65_Fid1, axis=1),np.mean(d4n7_Fid1, axis=1)])
meanfid2_d4 = np.array( [np.mean(d4n5_Fid2, axis=1),np.mean(d4n55_Fid2, axis=1),np.mean(d4n6_Fid2, axis=1),np.mean(d4n65_Fid2, axis=1),np.mean(d4n7_Fid2, axis=1)])

meanfid1_d8 = np.array( [np.mean(d8n5_Fid1, axis=1),np.mean(d8n55_Fid1, axis=1),np.mean(d8n6_Fid1, axis=1),np.mean(d8n65_Fid1, axis=1),np.mean(d8n7_Fid1, axis=1)])
meanfid2_d8 = np.array( [np.mean(d8n5_Fid2, axis=1),np.mean(d8n55_Fid2, axis=1),np.mean(d8n6_Fid2, axis=1),np.mean(d8n65_Fid2, axis=1),np.mean(d8n7_Fid2, axis=1)])

meanfid1_d16 = np.array( [np.mean(d16n5_Fid1, axis=1),np.mean(d16n55_Fid1, axis=1),np.mean(d16n6_Fid1, axis=1),np.mean(d16n65_Fid1, axis=1),np.mean(d16n7_Fid1, axis=1)])
meanfid2_d16 = np.array( [np.mean(d16n5_Fid2, axis=1),np.mean(d16n55_Fid2, axis=1),np.mean(d16n6_Fid2, axis=1),np.mean(d16n65_Fid2, axis=1),np.mean(d16n7_Fid2, axis=1)])

meanfid1_d32 = np.array( [np.mean(d32n5_Fid1, axis=1),np.mean(d32n55_Fid1, axis=1),np.mean(d32n6_Fid1, axis=1),np.mean(d32n65_Fid1, axis=1),np.mean(d32n7_Fid1, axis=1)])
meanfid2_d32 = np.array( [np.mean(d32n5_Fid2, axis=1),np.mean(d32n55_Fid2, axis=1),np.mean(d32n6_Fid2, axis=1),np.mean(d32n65_Fid2, axis=1),np.mean(d32n7_Fid2, axis=1)])

meanfid1_d64 = np.array( [np.mean(d64n5_Fid1, axis=1),np.mean(d64n55_Fid1, axis=1),np.mean(d64n6_Fid1, axis=1),np.mean(d64n65_Fid1, axis=1),np.mean(d64n7_Fid1, axis=1)])
meanfid2_d64 = np.array( [np.mean(d64n5_Fid2, axis=1),np.mean(d64n55_Fid2, axis=1),np.mean(d64n6_Fid2, axis=1),np.mean(d64n65_Fid2, axis=1),np.mean(d64n7_Fid2, axis=1)])

# Desviación estandar de las estimaciones

stdfid1_d4 = np.array( [np.std(d4n5_Fid1 , axis=1),np.std(d4n55_Fid1 , axis=1),np.std(d4n6_Fid1 , axis=1),np.std(d4n65_Fid1 , axis=1),np.std(d4n7_Fid1 , axis=1)])
stdfid2_d4 = np.array( [np.std(d4n5_Fid2 , axis=1),np.std(d4n55_Fid2 , axis=1),np.std(d4n6_Fid2 , axis=1),np.std(d4n65_Fid2 , axis=1),np.std(d4n7_Fid2 , axis=1)])

stdfid1_d8 = np.array( [np.std(d8n5_Fid1 , axis=1),np.std(d8n55_Fid1 , axis=1),np.std(d8n6_Fid1 , axis=1),np.std(d8n65_Fid1 , axis=1),np.std(d8n7_Fid1 , axis=1)])
stdfid2_d8 = np.array( [np.std(d8n5_Fid2 , axis=1),np.std(d8n55_Fid2 , axis=1),np.std(d8n6_Fid2 , axis=1),np.std(d8n65_Fid2 , axis=1),np.std(d8n7_Fid2 , axis=1)])

stdfid1_d16 = np.array( [np.std(d16n5_Fid1 , axis=1),np.std(d16n55_Fid1 , axis=1),np.std(d16n6_Fid1 , axis=1),np.std(d16n65_Fid1 , axis=1),np.std(d16n7_Fid1 , axis=1)])
stdfid2_d16 = np.array( [np.std(d16n5_Fid2 , axis=1),np.std(d16n55_Fid2 , axis=1),np.std(d16n6_Fid2 , axis=1),np.std(d16n65_Fid2 , axis=1),np.std(d16n7_Fid2 , axis=1)])

stdfid1_d32 = np.array( [np.std(d32n5_Fid1 , axis=1),np.std(d32n55_Fid1 , axis=1),np.std(d32n6_Fid1 , axis=1),np.std(d32n65_Fid1 , axis=1),np.std(d32n7_Fid1 , axis=1)])
stdfid2_d32 = np.array( [np.std(d32n5_Fid2 , axis=1),np.std(d32n55_Fid2 , axis=1),np.std(d32n6_Fid2 , axis=1),np.std(d32n65_Fid2 , axis=1),np.std(d32n7_Fid2 , axis=1)])

stdfid1_d64 = np.array( [np.std(d64n5_Fid1 , axis=1),np.std(d64n55_Fid1 , axis=1),np.std(d64n6_Fid1 , axis=1),np.std(d64n65_Fid1 , axis=1),np.std(d64n7_Fid1 , axis=1)])
stdfid2_d64 = np.array( [np.std(d64n5_Fid2 , axis=1),np.std(d64n55_Fid2 , axis=1),np.std(d64n6_Fid2 , axis=1),np.std(d64n65_Fid2 , axis=1),np.std(d64n7_Fid2 , axis=1)])

# %%
# GRAFICO PARA UN SOLO ESTADO DE LOS 100 RANDOM

shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2
i = 55

fig, axs = plt.subplots(2, 2, figsize=(12,10))

axs[0,0].loglog(dims, 1-meanfid1_n5[:,i], 'ro-', label='$N=10^{5}$')
axs[0,0].loglog(dims, GM(dims,10**5,shots), 'r--')
#axs[0,0].fill_between(dims, (1-meanfid1_n5[:,i])-stdfid1_n5[:,i], (1-meanfid2_n5[:,i])+stdfid1_n5[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,0].loglog(dims, 1-meanfid1_n55[:,i], 'bo-', label='$N=10^{5.5}$')
axs[0,0].loglog(dims, GM(dims,10**5.5,shots), 'b--')
#axs[0,0].fill_between(dims, (1-meanfid1_n55[:,i])-stdfid1_n55[:,i], (1-meanfid1_n55[:,i])+stdfid1_n55[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,0].loglog(dims, 1-meanfid1_n6[:,i], 'go-', label='$N=10^{6}$')
axs[0,0].loglog(dims, GM(dims,10**6,shots), 'g--')
#axs[0,0].fill_between(dims, (1-meanfid1_n6[:,i])-stdfid1_n6[:,i], (1-meanfid1_n6[:,i])+stdfid1_n6[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,0].loglog(dims, 1-meanfid1_n65[:,i], 'yo-', label='$N=10^{6.5}$')
axs[0,0].loglog(dims, GM(dims,10**6.5, shots), 'y--')
#axs[0,0].fill_between(dims, (1-meanfid1_n65[:,i])-stdfid2_n65[:,i], (1-meanfid1_n65[:,i])+stdfid1_n65[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,0].loglog(dims, 1-meanfid1_n7[:,i], 'co-', label='$N=10^{7}$')
axs[0,0].loglog(dims, GM(dims,10**7, shots), 'c--')
#axs[0,0].fill_between(dims, (1-meanfid1_n7[:,i])-stdfid2_n7[:,i], (1-meanfid1_n7[:,i])+stdfid1_n7[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,0].legend()
axs[0,0].set_xlabel('$d$',fontsize='14')
axs[0,0].set_ylabel(r'$\bar{I}$',fontsize='14')
axs[0,0].set_title('$1^{st}$ Estimation', fontsize='18')
axs[0,0].set_title('a)', loc='left', fontsize='18')

###########################################################################

axs[1,0].loglog(ens, 1-meanfid1_d4[:,i], 'ro-', label='$d=4$')
axs[1,0].loglog(ens, GM(4,ens,shots), 'r--')
#axs[1,0].fill_between(ens, (1-meanfid1_d4[:,i])-stdfid1_d4[:,i], (1-meanfid1_d4[:,i])+stdfid1_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,0].loglog(ens, 1-meanfid1_d8[:,i], 'bo-', label='$d=8$')
axs[1,0].loglog(ens, GM(8,ens,shots), 'b--')
#axs[1,0].fill_between(ens, (1-meanfid1_d8[:,i])-stdfid1_d8[:,i], (1-meanfid1_d8[:,i])+stdfid1_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,0].loglog(ens, 1-meanfid1_d16[:,i], 'go-', label='$d=16$')
axs[1,0].loglog(ens, GM(16,ens,shots), 'g--')
#axs[1,0].fill_between(ens, (1-meanfid1_d16[:,i])-stdfid1_d16[:,i], (1-meanfid1_d16[:,i])+stdfid1_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1,0].loglog(ens, 1-meanfid1_d32[:,i], 'yo-', label='$d=32$')
axs[1,0].loglog(ens, GM(32,ens, shots), 'y--')
#axs[1,0].fill_between(ens, (1-meanfid1_d32[:,i])-stdfid1_d32[:,i], (1-meanfid1_d32[:,i])+stdfid1_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1,0].loglog(ens, 1-meanfid1_d64[:,i], 'co-', label='$d=64$')
axs[1,0].loglog(ens, GM(64,ens, shots), 'c--')
#axs[1,0].fill_between(ens, (1-meanfid1_d64[:,i])-stdfid1_d64[:,i], (1-meanfid1_d64[:,i])+stdfid1_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,0].legend()
axs[1,0].set_xlabel('$N$',fontsize='14')
axs[1,0].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,0].set_title('$1^{nd}$ Estimation')
axs[1, 0].set_title('b)', loc='left', fontsize='18')


############################################################################################################

axs[0,1].loglog(dims, 1-meanfid2_n5[:,i], 'ro-', label='$N=10^{5}$')
axs[0,1].loglog(dims, GM(dims,10**5, 1), 'r--')
#axs[0,1].fill_between(dims, (1-meanfid2_n5[:,i])-stdfid2_n5[:,i], (1-meanfid2_n5[:,i])+stdfid2_n5[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,1].loglog(dims, 1-meanfid2_n55[:,i], 'bo-', label='$N=10^{5.5}$')
axs[0,1].loglog(dims, GM(dims,10**5.5, 1), 'b--')
#axs[0,1].fill_between(dims, (1-meanfid2_n55[:,i])-stdfid2_n55[:,i], (1-meanfid2_n55[:,i])+stdfid2_n55[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,1].loglog(dims, 1-meanfid2_n6[:,i], 'go-', label='$N=10^{6}$')
axs[0,1].loglog(dims, GM(dims,10**6, 1), 'g--')
#axs[0,1].fill_between(dims, (1-meanfid2_n6[:,i])-stdfid2_n6[:,i], (1-meanfid2_n6[:,i])+stdfid2_n6[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,1].loglog(dims, 1-meanfid2_n65[:,i], 'yo-', label='$N=10^{6.5}$')
axs[0,1].loglog(dims, GM(dims,10**6.5,  1), 'y--')
#axs[0,1].fill_between(dims, (1-meanfid2_n65[:,i])-stdfid2_n65[:,i], (1-meanfid2_n65[:,i])+stdfid2_n65[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,1].loglog(dims, 1-meanfid2_n7[:,i], 'co-', label='$N=10^{7}$')
axs[0,1].loglog(dims, GM(dims,10**7,  1), 'c--')
#axs[0,1].fill_between(dims, (1-meanfid2_n7[:,i])-stdfid2_n7[:,i], (1-meanfid2_n7[:,i])+stdfid2_n7[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,1].legend()
axs[0,1].set_xlabel('$d$',fontsize='14')
axs[0,1].set_ylabel(r'$\bar{I}$',fontsize='14')
axs[0,1].set_title('$2^{nd}$ Estimation', fontsize='18')
axs[0, 1].set_title('c)', loc='left', fontsize='18')

###########################################################################

axs[1,1].loglog(ens, 1-meanfid2_d4[:,i], 'ro-', label='$d=4$')
axs[1,1].loglog(ens, GM(4,ens, 1), 'r--')
#axs[1,1].fill_between(ens, (1-meanfid2_d4[:,i])-stdfid2_d4[:,i], (1-meanfid2_d4[:,i])+stdfid2_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,1].loglog(ens, 1-meanfid2_d8[:,i], 'bo-', label='$d=8$')
axs[1,1].loglog(ens, GM(8,ens, 1), 'b--')
#axs[1,1].fill_between(ens, (1-meanfid2_d8[:,i])-stdfid2_d8[:,i], (1-meanfid2_d8[:,i])+stdfid2_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,1].loglog(ens, 1-meanfid2_d16[:,i], 'go-', label='$d=16$')
axs[1,1].loglog(ens, GM(16,ens, 1), 'g--')
#axs[1,1].fill_between(ens, (1-meanfid2_d16[:,i])-stdfid2_d16[:,i], (1-meanfid2_d16[:,i])+stdfid2_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1,1].loglog(ens, 1-meanfid2_d32[:,i], 'yo-', label='$d=32$')
axs[1,1].loglog(ens, GM(32,ens,  1), 'y--')
#axs[1,1].fill_between(ens, (1-meanfid2_d32[:,i])-stdfid2_d32[:,i], (1-meanfid2_d32[:,i])+stdfid2_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1,1].loglog(ens, 1-meanfid2_d64[:,i], 'co-', label='$d=64$')
axs[1,1].loglog(ens, GM(64,ens,  1), 'c--')
#axs[1,1].fill_between(ens, (1-meanfid2_d64[:,i])-stdfid2_d64[:,i], (1-meanfid2_d64[:,i])+stdfid2_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,1].legend()
axs[1,1].set_xlabel('$N$',fontsize='14')
axs[1,1].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,1].set_title('$2^{nd}$ Estimation')
axs[1, 1].set_title('d)', loc='left', fontsize='18')

fig.suptitle('Distribution $2/4$', size=16)


plt.savefig('graf,1state24.pdf', bbox_inches='tight')

# %%
# GRAFICO PARA 4 ESTADOS RANDOM

shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2

fig, axs = plt.subplots(2, 2, figsize=(12,10))

axs[0,0].loglog(ens, 1-meanfid2_d4[:,19], 'ro-', label='$d=4$')
axs[0,0].loglog(ens, GM(4,ens, 1), 'r--')
#axs[1,1].fill_between(ens, (1-meanfid2_d4[:,i])-stdfid2_d4[:,i], (1-meanfid2_d4[:,i])+stdfid2_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,0].loglog(ens, 1-meanfid2_d8[:,19], 'bo-', label='$d=8$')
axs[0,0].loglog(ens, GM(8,ens, 1), 'b--')
#axs[1,1].fill_between(ens, (1-meanfid2_d8[:,i])-stdfid2_d8[:,i], (1-meanfid2_d8[:,i])+stdfid2_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,0].loglog(ens, 1-meanfid2_d16[:,19], 'go-', label='$d=16$')
axs[0,0].loglog(ens, GM(16,ens, 1), 'g--')
#axs[1,1].fill_between(ens, (1-meanfid2_d16[:,i])-stdfid2_d16[:,i], (1-meanfid2_d16[:,i])+stdfid2_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,0].loglog(ens, 1-meanfid2_d32[:,19], 'yo-', label='$d=32$')
axs[0,0].loglog(ens, GM(32,ens,  1), 'y--')
#axs[1,1].fill_between(ens, (1-meanfid2_d32[:,i])-stdfid2_d32[:,i], (1-meanfid2_d32[:,i])+stdfid2_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,0].loglog(ens, 1-meanfid2_d64[:,19], 'co-', label='$d=64$')
axs[0,0].loglog(ens, GM(64,ens,  1), 'c--')
#axs[1,1].fill_between(ens, (1-meanfid2_d64[:,i])-stdfid2_d64[:,i], (1-meanfid2_d64[:,i])+stdfid2_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,0].legend()
axs[0,0].set_xlabel('$N$',fontsize='14')
axs[0,0].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,1].set_title('$2^{nd}$ Estimation')

###########################################################################

axs[0,1].loglog(ens, 1-meanfid2_d4[:,92], 'ro-', label='$d=4$')
axs[0,1].loglog(ens, GM(4,ens, 1), 'r--')
#axs[1,1].fill_between(ens, (1-meanfid2_d4[:,i])-stdfid2_d4[:,i], (1-meanfid2_d4[:,i])+stdfid2_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,1].loglog(ens, 1-meanfid2_d8[:,92], 'bo-', label='$d=8$')
axs[0,1].loglog(ens, GM(8,ens, 1), 'b--')
#axs[1,1].fill_between(ens, (1-meanfid2_d8[:,i])-stdfid2_d8[:,i], (1-meanfid2_d8[:,i])+stdfid2_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,1].loglog(ens, 1-meanfid2_d16[:,92], 'go-', label='$d=16$')
axs[0,1].loglog(ens, GM(16,ens, 1), 'g--')
#axs[1,1].fill_between(ens, (1-meanfid2_d16[:,i])-stdfid2_d16[:,i], (1-meanfid2_d16[:,i])+stdfid2_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,1].loglog(ens, 1-meanfid2_d32[:,92], 'yo-', label='$d=32$')
axs[0,1].loglog(ens, GM(32,ens,  1), 'y--')
#axs[1,1].fill_between(ens, (1-meanfid2_d32[:,i])-stdfid2_d32[:,i], (1-meanfid2_d32[:,i])+stdfid2_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,1].loglog(ens, 1-meanfid2_d64[:,92], 'co-', label='$d=64$')
axs[0,1].loglog(ens, GM(64,ens,  1), 'c--')
#axs[1,1].fill_between(ens, (1-meanfid2_d64[:,i])-stdfid2_d64[:,i], (1-meanfid2_d64[:,i])+stdfid2_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,1].legend()
axs[0,1].set_xlabel('$N$',fontsize='14')
axs[0,1].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,1].set_title('$2^{nd}$ Estimation')

############################################################################################################

axs[1,0].loglog(ens, 1-meanfid2_d4[:,41], 'ro-', label='$d=4$')
axs[1,0].loglog(ens, GM(4,ens, 1), 'r--')
#axs[1,1].fill_between(ens, (1-meanfid2_d4[:,i])-stdfid2_d4[:,i], (1-meanfid2_d4[:,i])+stdfid2_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,0].loglog(ens, 1-meanfid2_d8[:,41], 'bo-', label='$d=8$')
axs[1,0].loglog(ens, GM(8,ens, 1), 'b--')
#axs[1,1].fill_between(ens, (1-meanfid2_d8[:,i])-stdfid2_d8[:,i], (1-meanfid2_d8[:,i])+stdfid2_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,0].loglog(ens, 1-meanfid2_d16[:,41], 'go-', label='$d=16$')
axs[1,0].loglog(ens, GM(16,ens, 1), 'g--')
#axs[1,1].fill_between(ens, (1-meanfid2_d16[:,i])-stdfid2_d16[:,i], (1-meanfid2_d16[:,i])+stdfid2_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1,0].loglog(ens, 1-meanfid2_d32[:,41], 'yo-', label='$d=32$')
axs[1,0].loglog(ens, GM(32,ens,  1), 'y--')
#axs[1,1].fill_between(ens, (1-meanfid2_d32[:,i])-stdfid2_d32[:,i], (1-meanfid2_d32[:,i])+stdfid2_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1,0].loglog(ens, 1-meanfid2_d64[:,41], 'co-', label='$d=64$')
axs[1,0].loglog(ens, GM(64,ens,  1), 'c--')
#axs[1,1].fill_between(ens, (1-meanfid2_d64[:,i])-stdfid2_d64[:,i], (1-meanfid2_d64[:,i])+stdfid2_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,0].legend()
axs[1,0].set_xlabel('$N$',fontsize='14')
axs[1,0].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,1].set_title('$2^{nd}$ Estimation')

###########################################################################

axs[1,1].loglog(ens, 1-meanfid2_d4[:,23], 'ro-', label='$d=4$')
axs[1,1].loglog(ens, GM(4,ens, 1), 'r--')
#axs[1,1].fill_between(ens, (1-meanfid2_d4[:,i])-stdfid2_d4[:,i], (1-meanfid2_d4[:,i])+stdfid2_d4[:,i], alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,1].loglog(ens, 1-meanfid2_d8[:,23], 'bo-', label='$d=8$')
axs[1,1].loglog(ens, GM(8,ens, 1), 'b--')
#axs[1,1].fill_between(ens, (1-meanfid2_d8[:,i])-stdfid2_d8[:,i], (1-meanfid2_d8[:,i])+stdfid2_d8[:,i], alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,1].loglog(ens, 1-meanfid2_d16[:,23], 'go-', label='$d=16$')
axs[1,1].loglog(ens, GM(16,ens, 1), 'g--')
#axs[1,1].fill_between(ens, (1-meanfid2_d16[:,i])-stdfid2_d16[:,i], (1-meanfid2_d16[:,i])+stdfid2_d16[:,i], alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1,1].loglog(ens, 1-meanfid2_d32[:,23], 'yo-', label='$d=32$')
axs[1,1].loglog(ens, GM(32,ens,  1), 'y--')
#axs[1,1].fill_between(ens, (1-meanfid2_d32[:,i])-stdfid2_d32[:,i], (1-meanfid2_d32[:,i])+stdfid2_d32[:,i], alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1,1].loglog(ens, 1-meanfid2_d64[:,23], 'co-', label='$d=64$')
axs[1,1].loglog(ens, GM(64,ens,  1), 'c--')
#axs[1,1].fill_between(ens, (1-meanfid2_d64[:,i])-stdfid2_d64[:,i], (1-meanfid2_d64[:,i])+stdfid2_d64[:,i], alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,1].legend()
axs[1,1].set_xlabel('$N$',fontsize='14')
axs[1,1].set_ylabel(r'$\bar{I}$',fontsize='14')
#axs[1,1].set_title('$2^{nd}$ Estimation')

fig.suptitle('$2^{nd}$ Estimation for 4 random states of dimension $d$, Distribution $2/4$', size=16)

plt.savefig('graf,4estados24.pdf', bbox_inches='tight')

# %% [markdown]
# ### 3. Ajustes de Curva
# A estimaciones de 1 estado.

# %%
# Paso 1, fitear para 1 coef de posición infidelidad vs dimension

ensamble = 10**np.array([5,5.5,6,6.5,7])
i = 92
shots = 1
d = 64

x = np.log10(shots*ensamble+1)
y = np.log10(1- meanfid2_d64[:,i])

#Ajuste
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

#Grafico
plt.figure()
plt.loglog(ensamble, 10**p(x), 'b-', label='Recta ajustada')
plt.loglog(ensamble , 10**y , 'ro', label='Datos')
plt.loglog(ensamble , (d-1)/10**x, 'm--', label='GM')

plt.xlabel('Ensamble')
plt.ylabel('Inf')

plt.legend()
#plt.title('Fit,$shots=2/4, dim=4$')
#plt.savefig('fitlineal,d=4,3est.pdf')

print('Ajuste para estados de dimensión', d)
print(f'Parámetros óptimos,$\\beta$=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )
#print('Matriz de covarianza =',z[1])
# Out:
# Ajuste para estados de dimensión 64
# Parámetros óptimos,$\beta$= -1.209573748787811 Desviación estándar = 0.10905643453642427

# %%
# Paso 1, fitear para 1 coef de posición infidelidad vs ensamble

n = 10**7
dims = 2**np.array([2,3,4,5,6])

x = np.log10(dims-1)
y = np.log10(1-meanfid2_n7[:,i])  #cambiar para cada ensamble, y cada estimación (0: 1a estimacion, 1: 2a estimacion, 2: 3a estimacion)

#Ajuste
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])


#Grafico
plt.figure()
plt.loglog(dims, 10**p(x), 'b-', label='Recta ajustada')
plt.loglog(dims , 10**y , 'ro', label='Datos')
plt.loglog(dims , (dims-1)/(n+1), 'm--', label='GM')

plt.xlabel('Dimensión')
plt.ylabel('Inf')

plt.legend()
#plt.title('Fit estimación 3, $n=10^{7}$')
#plt.savefig('doblefit,n7,-128.pdf')

print('Ajuste para ensambles=', np.log10(n))
print(f'Parámetros óptimos,$\\gamma$=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])
#print('Matriz de covarianza =',z[1])
# Out:
# Ajuste para ensambles= 7.0
# Parámetros óptimos,$\gamma$= 0.8975290301644092 Desviación estándar = 0.02231193898312443

# %%
np.mean([0.98,1.05,1.01,0.91,0.99])
# Out:
# 0.9880000000000001

# %%
## Ajuste con beta y gamma aproximados, para encontrar alpha

from scipy.optimize import curve_fit

# %%
 ##Primero definir función a fitear
beta = 1
gamma = 1

ensamble = 10**np.array([5,5.5,6,6.5,7])
dims = 2**np.array([2,3,4,5,6])

print('beta=',beta,'gamma=',gamma)


 # AJUSTE POR ENSAMBLE

print('Ajuste por ensamble')
def fun(d, alpha): #segunda estimación
    return np.log10(alpha) + gamma*np.log10((d-1)) - beta*np.log10(n+1)

x = 1-meanfid2_n5[:,i]
n = 10**5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_n55[:,i]
n = 10**5.5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_n6[:,i]
n = 10**6
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_n65[:,i]
n = 10**6.5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_n7[:,i]
n = 10**7
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))


plt.loglog(dims, x ,'ro')
plt.loglog(dims, 10**fun(dims,popt), 'r--')

# AJUSTE POR DIMENSIÓN

print('Ajuste por dimensión')
def fun(n, alpha): #segunda estimación
    return np.log10(alpha) + gamma*np.log10((d-1)) - beta*np.log10(n+1)

x = 1-meanfid2_d4[:,i]
d = 4
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_d8[:,i]
d = 8
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_d16[:,i]
d = 16
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_d32[:,i]
d = 32
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-meanfid2_d64[:,i]
d = 64
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))
# Out:
# beta= 1 gamma= 1
# Ajuste por ensamble
# n= 5.0 $alpha$= [1.73405579] error= [[0.40818945]]
# n= 5.5 $alpha$= [1.38098041] error= [[0.07888829]]
# n= 6.0 $alpha$= [1.31850006] error= [[0.04934443]]
# n= 6.5 $alpha$= [1.4488404] error= [[0.02944801]]
# n= 7.0 $alpha$= [1.5199191] error= [[0.08924179]]
# Ajuste por dimensión
# d= 4 $alpha$= [1.44125119] error= [[0.11375826]]
# d= 8 $alpha$= [1.29432064] error= [[0.07490604]]
# d= 16 $alpha$= [1.46617191] error= [[0.03419249]]
# d= 32 $alpha$= [1.44941529] error= [[0.01786499]]
# d= 64 $alpha$= [1.75393084] error= [[0.40284071]]

# %% [markdown]
# ## 4. Grafico de media de estimación en todos los estados

# %%
md4n5_Fid1 = np.mean(d4n5_Fid1, axis=1)
md4n5_Fid2 = np.mean(d4n5_Fid2, axis=1)
md4n55_Fid1 = np.mean(d4n55_Fid1, axis=1)
md4n55_Fid2 = np.mean(d4n55_Fid2, axis=1)
md4n6_Fid1 = np.mean(d4n6_Fid1, axis=1)
md4n6_Fid2 = np.mean(d4n6_Fid2, axis=1)
md4n65_Fid1 = np.mean(d4n65_Fid1, axis=1)
md4n65_Fid2 = np.mean(d4n65_Fid2, axis=1)
md4n7_Fid1 = np.mean(d4n7_Fid1, axis=1)
md4n7_Fid2 = np.mean(d4n7_Fid2, axis=1)

md8n5_Fid1 = np.mean(d8n5_Fid1, axis=1)
md8n5_Fid2 = np.mean(d8n5_Fid2, axis=1)
md8n55_Fid1 = np.mean(d8n55_Fid1, axis=1)
md8n55_Fid2 = np.mean(d8n55_Fid2, axis=1)
md8n6_Fid1 = np.mean(d8n6_Fid1, axis=1)
md8n6_Fid2 = np.mean(d8n6_Fid2, axis=1)
md8n65_Fid1 = np.mean(d8n65_Fid1, axis=1)
md8n65_Fid2 = np.mean(d8n65_Fid2, axis=1)
md8n7_Fid1 = np.mean(d8n7_Fid1, axis=1)
md8n7_Fid2 = np.mean(d8n7_Fid2, axis=1)

md16n5_Fid1 = np.mean(d16n5_Fid1, axis=1)
md16n5_Fid2 = np.mean(d16n5_Fid2, axis=1)
md16n55_Fid1 = np.mean(d16n55_Fid1, axis=1)
md16n55_Fid2 = np.mean(d16n55_Fid2, axis=1)
md16n6_Fid1 = np.mean(d16n6_Fid1, axis=1)
md16n6_Fid2 = np.mean(d16n6_Fid2, axis=1)
md16n65_Fid1 = np.mean(d16n65_Fid1, axis=1)
md16n65_Fid2 = np.mean(d16n65_Fid2, axis=1)
md16n7_Fid1 = np.mean(d16n7_Fid1, axis=1)
md16n7_Fid2 = np.mean(d16n7_Fid2, axis=1)

md32n5_Fid1 = np.mean(d32n5_Fid1, axis=1)
md32n5_Fid2 = np.mean(d32n5_Fid2, axis=1)
md32n55_Fid1 = np.mean(d32n55_Fid1, axis=1)
md32n55_Fid2 = np.mean(d32n55_Fid2, axis=1)
md32n6_Fid1 = np.mean(d32n6_Fid1, axis=1)
md32n6_Fid2 = np.mean(d32n6_Fid2, axis=1)
md32n65_Fid1 = np.mean(d32n65_Fid1, axis=1)
md32n65_Fid2 = np.mean(d32n65_Fid2, axis=1)
md32n7_Fid1 = np.mean(d32n7_Fid1, axis=1)
md32n7_Fid2 = np.mean(d32n7_Fid2, axis=1)

md64n5_Fid1 = np.mean(d64n5_Fid1, axis=1)
md64n5_Fid2 = np.mean(d64n5_Fid2, axis=1)
md64n55_Fid1 = np.mean(d64n55_Fid1, axis=1)
md64n55_Fid2 = np.mean(d64n55_Fid2, axis=1)
md64n6_Fid1 = np.mean(d64n6_Fid1, axis=1)
md64n6_Fid2 = np.mean(d64n6_Fid2, axis=1)
md64n65_Fid1 = np.mean(d64n65_Fid1, axis=1)
md64n65_Fid2 = np.mean(d64n65_Fid2, axis=1)
md64n7_Fid1 = np.mean(d64n7_Fid1, axis=1)
md64n7_Fid2 = np.mean(d64n7_Fid2, axis=1)

# %%
## Infidelidad vs Dimensión para distintos Ensambles


mmeanfid1_n5 = np.array( [np.mean(md4n5_Fid1),np.mean(md8n5_Fid1), np.mean(md16n5_Fid1), np.mean(md32n5_Fid1),np.mean(md64n5_Fid1)])
mmeanfid2_n5 = np.array( [np.mean(md4n5_Fid2),np.mean(md8n5_Fid2), np.mean(md16n5_Fid2), np.mean(md32n5_Fid2),np.mean(md64n5_Fid2)])

mmeanfid1_n55 = np.array( [np.mean(md4n55_Fid1),np.mean(md8n55_Fid1), np.mean(md16n55_Fid1), np.mean(md32n55_Fid1),np.mean(md64n55_Fid1)])
mmeanfid2_n55 = np.array( [np.mean(md4n55_Fid2),np.mean(md8n55_Fid2), np.mean(md16n55_Fid2), np.mean(md32n55_Fid2),np.mean(md64n55_Fid2)])

mmeanfid1_n6 = np.array( [np.mean(md4n6_Fid1),np.mean(md8n6_Fid1), np.mean(md16n6_Fid1), np.mean(d32n6_Fid1),np.mean(d64n6_Fid1)])
mmeanfid2_n6 = np.array( [np.mean(md4n6_Fid2),np.mean(md8n6_Fid2), np.mean(md16n6_Fid2), np.mean(d32n6_Fid2),np.mean(d64n6_Fid2)])

mmeanfid1_n65 = np.array( [np.mean(md4n65_Fid1),np.mean(md8n65_Fid1), np.mean(md16n65_Fid1), np.mean(md32n65_Fid1),np.mean(md64n65_Fid1)])
mmeanfid2_n65 = np.array( [np.mean(md4n65_Fid2),np.mean(md8n65_Fid2), np.mean(md16n65_Fid2), np.mean(md32n65_Fid2),np.mean(md64n65_Fid2)])

mmeanfid1_n7 = np.array( [np.mean(md4n7_Fid1),np.mean(md8n7_Fid1), np.mean(md16n7_Fid1), np.mean(md32n7_Fid1),np.mean(md64n7_Fid1)])
mmeanfid2_n7 = np.array( [np.mean(md4n7_Fid2),np.mean(md8n7_Fid2), np.mean(md16n7_Fid2), np.mean(md32n7_Fid2),np.mean(md64n7_Fid2)])

# Desviación estándar de las fidelidades de las 10 estimaciones de cada estado random por dimension y ensamble

mstdfid1_n5 = np.array( [np.std(md4n5_Fid1),np.std(md8n5_Fid1), np.std(md16n5_Fid1), np.std(md32n5_Fid1),np.std(md64n5_Fid1)])
mstdfid2_n5 = np.array( [np.std(md4n5_Fid2),np.std(md8n5_Fid2), np.std(md16n5_Fid2), np.std(md32n5_Fid2),np.std(md64n5_Fid2)])

mstdfid1_n55 = np.array( [np.std(md4n55_Fid1),np.std(md8n55_Fid1), np.std(md16n55_Fid1), np.std(md32n55_Fid1),np.std(md64n55_Fid1)])
mstdfid2_n55 = np.array( [np.std(md4n55_Fid2),np.std(md8n55_Fid2), np.std(md16n55_Fid2), np.std(md32n55_Fid2),np.std(md64n55_Fid2)])

mstdfid1_n6 = np.array( [np.std(md4n6_Fid1),np.std(md8n6_Fid1), np.std(md16n6_Fid1), np.std(md32n6_Fid1),np.std(md64n6_Fid1)])
mstdfid2_n6 = np.array( [np.std(md4n6_Fid2),np.std(md8n6_Fid2), np.std(md16n6_Fid2), np.std(md32n6_Fid2),np.std(md64n6_Fid2)])

mstdfid1_n65 = np.array( [np.std(md4n65_Fid1),np.std(md8n65_Fid1), np.std(md16n65_Fid1), np.std(md32n65_Fid1),np.std(md64n65_Fid1)])
mstdfid2_n65 = np.array( [np.std(md4n65_Fid2),np.std(md8n65_Fid2), np.std(md16n65_Fid2), np.std(md32n65_Fid2),np.std(md64n65_Fid2)])

mstdfid1_n7 = np.array( [np.std(md4n7_Fid1),np.std(md8n7_Fid1), np.std(md16n7_Fid1), np.std(md32n7_Fid1),np.std(md64n7_Fid1)])
mstdfid2_n7 = np.array( [np.std(md4n7_Fid2),np.std(md8n7_Fid2), np.std(md16n7_Fid2), np.std(md32n7_Fid2),np.std(md64n7_Fid2)])

# %%
## Infidelidad vs Ensamble para distintas dimensiones

# Media de la fidelidad para 10 estimaciones de 1 estado random para cada dimension y ensamble


mmeanfid1_d4 = np.array( [np.mean(md4n5_Fid1),np.mean(md4n55_Fid1),np.mean(md4n6_Fid1),np.mean(md4n65_Fid1),np.mean(md4n7_Fid1)])
mmeanfid2_d4 = np.array( [np.mean(md4n5_Fid2),np.mean(md4n55_Fid2),np.mean(md4n6_Fid2),np.mean(md4n65_Fid2),np.mean(md4n7_Fid2)])

mmeanfid1_d8 = np.array( [np.mean(md8n5_Fid1),np.mean(md8n55_Fid1),np.mean(md8n6_Fid1),np.mean(md8n65_Fid1),np.mean(md8n7_Fid1)])
mmeanfid2_d8 = np.array( [np.mean(md8n5_Fid2),np.mean(md8n55_Fid2),np.mean(md8n6_Fid2),np.mean(md8n65_Fid2),np.mean(md8n7_Fid2)])

mmeanfid1_d16 = np.array( [np.mean(md16n5_Fid1),np.mean(md16n55_Fid1),np.mean(md16n6_Fid1),np.mean(md16n65_Fid1),np.mean(md16n7_Fid1)])
mmeanfid2_d16 = np.array( [np.mean(md16n5_Fid2),np.mean(md16n55_Fid2),np.mean(md16n6_Fid2),np.mean(md16n65_Fid2),np.mean(md16n7_Fid2)])

mmeanfid1_d32 = np.array( [np.mean(md32n5_Fid1),np.mean(md32n55_Fid1),np.mean(md32n6_Fid1),np.mean(md32n65_Fid1),np.mean(md32n7_Fid1)])
mmeanfid2_d32 = np.array( [np.mean(md32n5_Fid2),np.mean(md32n55_Fid2),np.mean(md32n6_Fid2),np.mean(md32n65_Fid2),np.mean(md32n7_Fid2)])

mmeanfid1_d64 = np.array( [np.mean(md64n5_Fid1),np.mean(md64n55_Fid1),np.mean(md64n6_Fid1),np.mean(md64n65_Fid1),np.mean(md64n7_Fid1)])
mmeanfid2_d64 = np.array( [np.mean(md64n5_Fid2),np.mean(md64n55_Fid2),np.mean(md64n6_Fid2),np.mean(md64n65_Fid2),np.mean(md64n7_Fid2)])

# Desviación estandar de las estimaciones

mstdfid1_d4 = np.array( [np.std(md4n5_Fid1),np.std(md4n55_Fid1),np.std(md4n6_Fid1),np.std(md4n65_Fid1),np.std(md4n7_Fid1)])
mstdfid2_d4 = np.array( [np.std(md4n5_Fid2),np.std(md4n55_Fid2),np.std(md4n6_Fid2),np.std(md4n65_Fid2),np.std(md4n7_Fid2)])

mstdfid1_d8 = np.array( [np.std(md8n5_Fid1),np.std(md8n55_Fid1),np.std(md8n6_Fid1),np.std(md8n65_Fid1),np.std(md8n7_Fid1)])
mstdfid2_d8 = np.array( [np.std(md8n5_Fid2),np.std(md8n55_Fid2),np.std(md8n6_Fid2),np.std(md8n65_Fid2),np.std(md8n7_Fid2)])

mstdfid1_d16 = np.array( [np.std(md16n5_Fid1),np.std(md16n55_Fid1),np.std(md16n6_Fid1),np.std(md16n65_Fid1),np.std(md16n7_Fid1)])
mstdfid2_d16 = np.array( [np.std(md16n5_Fid2),np.std(md16n55_Fid2),np.std(md16n6_Fid2),np.std(md16n65_Fid2),np.std(md16n7_Fid2)])

mstdfid1_d32 = np.array( [np.std(md32n5_Fid1),np.std(md32n55_Fid1),np.std(md32n6_Fid1),np.std(md32n65_Fid1),np.std(md32n7_Fid1)])
mstdfid2_d32 = np.array( [np.std(md32n5_Fid2),np.std(md32n55_Fid2),np.std(md32n6_Fid2),np.std(md32n65_Fid2),np.std(md32n7_Fid2)])

mstdfid1_d64 = np.array( [np.std(md64n5_Fid1),np.std(md64n55_Fid1),np.std(md64n6_Fid1),np.std(md64n65_Fid1),np.std(md64n7_Fid1)])
mstdfid2_d64 = np.array( [np.std(md64n5_Fid2),np.std(md64n55_Fid2),np.std(md64n6_Fid2),np.std(md64n65_Fid2),np.std(md64n7_Fid2)])

# %%
shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2

fig, axs = plt.subplots(2, 2, figsize=(12,10))

axs[0,0].loglog(dims, 1-mmeanfid1_n5, 'ro-', label='$N=10^{5}$')
axs[0,0].loglog(dims, GM(dims,10**5,shots), 'r--')
axs[0,0].errorbar(dims, 1-mmeanfid1_n5, mstdfid1_n5, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[0].fill_between(dims, (1-mmeanfid1_n5)-mstdfid1_n5, (1-mmeanfid1_n5)+mstdfid1_n5, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,0].loglog(dims, 1-mmeanfid1_n55, 'bo-', label='$N=10^{5.5}$')
axs[0,0].loglog(dims, GM(dims,10**5.5,shots), 'b--')
axs[0,0].errorbar(dims, 1-mmeanfid1_n55, mstdfid1_n55, fmt='none', linewidth=2, capsize=6 , ecolor='blue')
#axs[0].fill_between(dims, (1-mmeanfid2_n55)-mstdfid2_n55, (1-mmeanfid2_n55)+mstdfid2_n55, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,0].loglog(dims, 1-mmeanfid1_n6, 'go-', label='$N=10^{6}$')
axs[0,0].loglog(dims, GM(dims,10**6,shots), 'g--')
axs[0,0].errorbar(dims, 1-mmeanfid1_n6, mstdfid1_n6, fmt='none', linewidth=2, capsize=6 , ecolor='green')
#axs[0].fill_between(dims, (1-mmeanfid2_n6)-mstdfid2_n6, (1-mmeanfid2_n6)+mstdfid2_n6, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,0].loglog(dims, 1-mmeanfid1_n65, 'yo-', label='$N=10^{6.5}$')
axs[0,0].loglog(dims, GM(dims,10**6.5, shots), 'y--')
axs[0,0].errorbar(dims, 1-mmeanfid1_n65, mstdfid1_n65, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[0].fill_between(dims, (1-mmeanfid2_n65)-mstdfid2_n65, (1-mmeanfid2_n65)+mstdfid2_n65, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,0].loglog(dims, 1-mmeanfid1_n7, 'co-', label='$N=10^{7}$')
axs[0,0].loglog(dims, GM(dims,10**7, shots), 'c--')
axs[0,0].errorbar(dims, 1-mmeanfid1_n7, mstdfid1_n7, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[0].fill_between(dims, (1-mmeanfid2_n7)-mstdfid2_n7, (1-mmeanfid2_n7)+mstdfid2_n7, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,0].legend()
axs[0,0].set_xlim([3.5,70])
axs[0,0].set_xlabel('$d$', fontsize='14')
axs[0,0].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[0,0].set_title('$1^{st}$ Estimation', fontsize='18')
axs[0,0].set_title('a)', loc='left', fontsize='18')

###########################################################################

axs[1,0].loglog(ens, 1-mmeanfid1_d4, 'ro-', label='$d=4$')
axs[1,0].loglog(ens, GM(4,ens,shots), 'r--')
axs[1,0].errorbar(ens, 1-mmeanfid1_d4, mstdfid1_d4, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d4)-mstdfid2_d4, (1-mmeanfid2_d4)+mstdfid2_d4, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,0].loglog(ens, 1-mmeanfid1_d8, 'bo-', label='$d=8$')
axs[1,0].loglog(ens, GM(8,ens,shots), 'b--')
axs[1,0].errorbar(ens, 1-mmeanfid1_d8, mstdfid1_d8, fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d8)-mstdfid2_d8, (1-mmeanfid2_d8)+mstdfid2_d8, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,0].loglog(ens, 1-mmeanfid1_d16, 'go-', label='$d=16$')
axs[1,0].loglog(ens, GM(16,ens,shots), 'g--')
axs[1,0].errorbar(ens, 1-mmeanfid1_d16, mstdfid1_d16, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d16)-mstdfid2_d16, (1-mmeanfid2_d16)+mstdfid2_d16, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1,0].loglog(ens, 1-mmeanfid1_d32, 'yo-', label='$d=32$')
axs[1,0].loglog(ens, GM(32,ens, shots), 'y--')
axs[1,0].errorbar(ens, 1-mmeanfid1_d32, mstdfid1_d32, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d32)-mstdfid2_d32, (1-mmeanfid2_d32)+mstdfid2_d32, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1,0].loglog(ens, 1-mmeanfid1_d64, 'co-', label='$d=64$')
axs[1,0].loglog(ens, GM(64,ens, shots), 'c--')
axs[1,0].errorbar(ens, 1-mmeanfid1_d64, mstdfid1_d64, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d64)-mstdfid2_d64, (1-mmeanfid2_d64)+mstdfid2_d64, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,0].legend()
axs[1,0].set_xlim([10**4.9,10**7.1])
axs[1,0].set_xlabel('N', fontsize='14')
axs[1,0].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[1,0].set_title('b)', loc='left', fontsize='18')

######################################################################################
######################################################################################

axs[0,1].loglog(dims, 1-mmeanfid2_n5, 'ro-', label='$N=10^{5}$')
axs[0,1].loglog(dims, GM(dims,10**5,1), 'r--')
axs[0,1].errorbar(dims, 1-mmeanfid2_n5, mstdfid2_n5, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n5)-mstdfid2_n5, (1-mmeanfid2_n5)+mstdfid2_n5, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0,1].loglog(dims, 1-mmeanfid2_n55, 'bo-', label='$N=10^{5.5}$')
axs[0,1].loglog(dims, GM(dims,10**5.5,1), 'b--')
axs[0,1].errorbar(dims, 1-mmeanfid2_n55, mstdfid2_n55, fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n55)-mstdfid2_n55, (1-mmeanfid2_n55)+mstdfid2_n55, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0,1].loglog(dims, 1-mmeanfid2_n6, 'go-', label='$N=10^{6}$')
axs[0,1].loglog(dims, GM(dims,10**6,1), 'g--')
axs[0,1].errorbar(dims, 1-mmeanfid2_n6, mstdfid2_n6, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n6)-mstdfid2_n6, (1-mmeanfid2_n6)+mstdfid2_n6, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0,1].loglog(dims, 1-mmeanfid2_n65, 'yo-', label='$N=10^{6.5}$')
axs[0,1].loglog(dims, GM(dims,10**6.5, 1), 'y--')
axs[0,1].errorbar(dims, 1-mmeanfid2_n65, mstdfid2_n65, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n65)-mstdfid2_n65, (1-mmeanfid2_n65)+mstdfid2_n65, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0,1].loglog(dims, 1-mmeanfid2_n7, 'co-', label='$N=10^{7}$')
axs[0,1].loglog(dims, GM(dims,10**7, 1), 'c--')
axs[0,1].errorbar(dims, 1-mmeanfid2_n7, mstdfid2_n7, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n7)-mstdfid2_n7, (1-mmeanfid2_n7)+mstdfid2_n7, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0,1].legend()
axs[0,1].set_xlim([3.5,70])
axs[0,1].set_xlabel('$d$', fontsize='14')
axs[0,1].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[0,1].set_title('$2^{nd}$ Estimation', fontsize='18')
axs[0,1].set_title('c)', loc='left', fontsize='18')

###########################################################################

axs[1,1].loglog(ens, 1-mmeanfid2_d64, 'co-', label='$d=64$')
axs[1,1].loglog(ens, GM(64,ens, 1), 'c--')
axs[1,1].errorbar(ens, 1-mmeanfid2_d64, mstdfid2_d64, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d64)-mstdfid2_d64, (1-mmeanfid2_d64)+mstdfid2_d64, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1,1].loglog(ens, 1-mmeanfid2_d32, 'yo-', label='$d=32$')
axs[1,1].loglog(ens, GM(32,ens, 1), 'y--')
axs[1,1].errorbar(ens, 1-mmeanfid2_d32, mstdfid2_d32, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d32)-mstdfid2_d32, (1-mmeanfid2_d32)+mstdfid2_d32, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')

axs[1,1].loglog(ens, 1-mmeanfid2_d4, 'ro-', label='$d=4$')
axs[1,1].loglog(ens, GM(4,ens,1), 'r--')
axs[1,1].errorbar(ens, 1-mmeanfid2_d4, mstdfid2_d4, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d4)-mstdfid2_d4, (1-mmeanfid2_d4)+mstdfid2_d4, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1,1].loglog(ens, 1-mmeanfid2_d8, 'bo-', label='$d=8$')
axs[1,1].loglog(ens, GM(8,ens,1), 'b--')
axs[1,1].errorbar(ens, 1-mmeanfid2_d8, mstdfid2_d8 , fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d8)-mstdfid2_d8, (1-mmeanfid2_d8)+mstdfid2_d8, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1,1].loglog(ens, 1-mmeanfid2_d16, 'go-', label='$d=16$')
axs[1,1].loglog(ens, GM(16,ens,1), 'g--')
axs[1,1].errorbar(ens, 1-mmeanfid2_d16 , mstdfid2_d16, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d16)-mstdfid2_d16, (1-mmeanfid2_d16)+mstdfid2_d16, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')





axs[1,1].legend()
axs[1,1].set_xlim([10**4.9,10**7.1])
axs[1,1].set_xlabel('$N$', fontsize='14')
axs[1,1].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
#axs[1, 1].set_title('$2^a$ Estimación, $Shots_1=2/5$')
axs[1,1].set_title('d)', loc='left', fontsize='18')

#fig.suptitle('Distribution $2/4$', size=16)

plt.savefig('graf,STD24.pdf', bbox_inches='tight')

# %%
shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2

fig, axs = plt.subplots(2, 1, figsize=(8,12))

axs[0].loglog(dims, 1-mmeanfid1_n5, 'ro-', label='$N=10^{5}$')
axs[0].loglog(dims, GM(dims,10**5,shots), 'r--')
axs[0].errorbar(dims, 1-mmeanfid1_n5, mstdfid1_n5, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[0].fill_between(dims, (1-mmeanfid1_n5)-mstdfid1_n5, (1-mmeanfid1_n5)+mstdfid1_n5, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0].loglog(dims, 1-mmeanfid1_n55, 'bo-', label='$N=10^{5.5}$')
axs[0].loglog(dims, GM(dims,10**5.5,shots), 'b--')
axs[0].errorbar(dims, 1-mmeanfid1_n55, mstdfid1_n55, fmt='none', linewidth=2, capsize=6 , ecolor='blue')
#axs[0].fill_between(dims, (1-mmeanfid2_n55)-mstdfid2_n55, (1-mmeanfid2_n55)+mstdfid2_n55, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0].loglog(dims, 1-mmeanfid1_n6, 'go-', label='$N=10^{6}$')
axs[0].loglog(dims, GM(dims,10**6,shots), 'g--')
axs[0].errorbar(dims, 1-mmeanfid1_n6, mstdfid1_n6, fmt='none', linewidth=2, capsize=6 , ecolor='green')
#axs[0].fill_between(dims, (1-mmeanfid2_n6)-mstdfid2_n6, (1-mmeanfid2_n6)+mstdfid2_n6, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0].loglog(dims, 1-mmeanfid1_n65, 'yo-', label='$N=10^{6.5}$')
axs[0].loglog(dims, GM(dims,10**6.5, shots), 'y--')
axs[0].errorbar(dims, 1-mmeanfid1_n65, mstdfid1_n65, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[0].fill_between(dims, (1-mmeanfid2_n65)-mstdfid2_n65, (1-mmeanfid2_n65)+mstdfid2_n65, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0].loglog(dims, 1-mmeanfid1_n7, 'co-', label='$N=10^{7}$')
axs[0].loglog(dims, GM(dims,10**7, shots), 'c--')
axs[0].errorbar(dims, 1-mmeanfid1_n7, mstdfid1_n7, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[0].fill_between(dims, (1-mmeanfid2_n7)-mstdfid2_n7, (1-mmeanfid2_n7)+mstdfid2_n7, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0].legend()
axs[0].set_xlim([3.5,70])
axs[0].set_xlabel('$d$', fontsize='14')
axs[0].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[0].set_title('$1^{st}$ Estimation', fontsize='18')
axs[0].set_title('a)', loc='left', fontsize='18')

###########################################################################

axs[1].loglog(ens, 1-mmeanfid1_d4, 'ro-', label='$d=4$')
axs[1].loglog(ens, GM(4,ens,shots), 'r--')
axs[1].errorbar(ens, 1-mmeanfid1_d4, mstdfid1_d4, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d4)-mstdfid2_d4, (1-mmeanfid2_d4)+mstdfid2_d4, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1].loglog(ens, 1-mmeanfid1_d8, 'bo-', label='$d=8$')
axs[1].loglog(ens, GM(8,ens,shots), 'b--')
axs[1].errorbar(ens, 1-mmeanfid1_d8, mstdfid1_d8, fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d8)-mstdfid2_d8, (1-mmeanfid2_d8)+mstdfid2_d8, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1].loglog(ens, 1-mmeanfid1_d16, 'go-', label='$d=16$')
axs[1].loglog(ens, GM(16,ens,shots), 'g--')
axs[1].errorbar(ens, 1-mmeanfid1_d16, mstdfid1_d16, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d16)-mstdfid2_d16, (1-mmeanfid2_d16)+mstdfid2_d16, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1].loglog(ens, 1-mmeanfid1_d32, 'yo-', label='$d=32$')
axs[1].loglog(ens, GM(32,ens, shots), 'y--')
axs[1].errorbar(ens, 1-mmeanfid1_d32, mstdfid1_d32, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d32)-mstdfid2_d32, (1-mmeanfid2_d32)+mstdfid2_d32, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1].loglog(ens, 1-mmeanfid1_d64, 'co-', label='$d=64$')
axs[1].loglog(ens, GM(64,ens, shots), 'c--')
axs[1].errorbar(ens, 1-mmeanfid1_d64, mstdfid1_d64, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[1,0].fill_between(ens, (1-mmeanfid2_d64)-mstdfid2_d64, (1-mmeanfid2_d64)+mstdfid2_d64, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1].legend()
axs[1].set_xlim([10**4.9,10**7.1])
axs[1].set_xlabel('N', fontsize='14')
axs[1].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[1].set_title('b)', loc='left', fontsize='18')



######################################################################################

plt.savefig('graf,step1,STD24.pdf', bbox_inches='tight')

# %%
shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2

fig, axs = plt.subplots(2, 1, figsize=(8,12))

######################################################################################

axs[0].loglog(dims, 1-mmeanfid2_n5, 'ro-', label='$N=10^{5}$')
axs[0].loglog(dims, GM(dims,10**5,1), 'r--')
axs[0].errorbar(dims, 1-mmeanfid2_n5, mstdfid2_n5, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n5)-mstdfid2_n5, (1-mmeanfid2_n5)+mstdfid2_n5, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0].loglog(dims, 1-mmeanfid2_n55, 'bo-', label='$N=10^{5.5}$')
axs[0].loglog(dims, GM(dims,10**5.5,1), 'b--')
axs[0].errorbar(dims, 1-mmeanfid2_n55, mstdfid2_n55, fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n55)-mstdfid2_n55, (1-mmeanfid2_n55)+mstdfid2_n55, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0].loglog(dims, 1-mmeanfid2_n6, 'go-', label='$N=10^{6}$')
axs[0].loglog(dims, GM(dims,10**6,1), 'g--')
axs[0].errorbar(dims, 1-mmeanfid2_n6, mstdfid2_n6, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n6)-mstdfid2_n6, (1-mmeanfid2_n6)+mstdfid2_n6, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0].loglog(dims, 1-mmeanfid2_n65, 'yo-', label='$N=10^{6.5}$')
axs[0].loglog(dims, GM(dims,10**6.5, 1), 'y--')
axs[0].errorbar(dims, 1-mmeanfid2_n65, mstdfid2_n65, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n65)-mstdfid2_n65, (1-mmeanfid2_n65)+mstdfid2_n65, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0].loglog(dims, 1-mmeanfid2_n7, 'co-', label='$N=10^{7}$')
axs[0].loglog(dims, GM(dims,10**7, 1), 'c--')
axs[0].errorbar(dims, 1-mmeanfid2_n7, mstdfid2_n7, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[0,1].fill_between(dims, (1-mmeanfid2_n7)-mstdfid2_n7, (1-mmeanfid2_n7)+mstdfid2_n7, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0].legend()
axs[0].set_xlim([3.5,70])
axs[0].set_xlabel('$d$', fontsize='14')
axs[0].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
axs[0].set_title('$2^{nd}$ Estimation', fontsize='18')
axs[0].set_title('a)', loc='left', fontsize='18')

###########################################################################

axs[1].loglog(ens, 1-mmeanfid2_d64, 'co-', label='$d=64$')
axs[1].loglog(ens, GM(64,ens, 1), 'c--')
axs[1].errorbar(ens, 1-mmeanfid2_d64, mstdfid2_d64, fmt='none', linewidth=2, capsize=6 , ecolor='c')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d64)-mstdfid2_d64, (1-mmeanfid2_d64)+mstdfid2_d64, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')
axs[1].loglog(ens, 1-mmeanfid2_d32, 'yo-', label='$d=32$')
axs[1].loglog(ens, GM(32,ens, 1), 'y--')
axs[1].errorbar(ens, 1-mmeanfid2_d32, mstdfid2_d32, fmt='none', linewidth=2, capsize=6 , ecolor='y')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d32)-mstdfid2_d32, (1-mmeanfid2_d32)+mstdfid2_d32, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1].loglog(ens, 1-mmeanfid2_d4, 'ro-', label='$d=4$')
axs[1].loglog(ens, GM(4,ens,1), 'r--')
axs[1].errorbar(ens, 1-mmeanfid2_d4, mstdfid2_d4, fmt='none', linewidth=2, capsize=6 , ecolor='red')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d4)-mstdfid2_d4, (1-mmeanfid2_d4)+mstdfid2_d4, alpha=alpha, color='r')
axs[1].loglog(ens, 1-mmeanfid2_d8, 'bo-', label='$d=8$')
axs[1].loglog(ens, GM(8,ens,1), 'b--')
axs[1].errorbar(ens, 1-mmeanfid2_d8, mstdfid2_d8 , fmt='none', linewidth=2, capsize=6 , ecolor='b')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d8)-mstdfid2_d8, (1-mmeanfid2_d8)+mstdfid2_d8, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1].loglog(ens, 1-mmeanfid2_d16, 'go-', label='$d=16$')
axs[1].loglog(ens, GM(16,ens,1), 'g--')
axs[1].errorbar(ens, 1-mmeanfid2_d16 , mstdfid2_d16, fmt='none', linewidth=2, capsize=6 , ecolor='g')
#axs[1,1].fill_between(ens, (1-mmeanfid2_d16)-mstdfid2_d16, (1-mmeanfid2_d16)+mstdfid2_d16, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')



axs[1].legend()
axs[1].set_xlim([10**4.9,10**7.1])
axs[1].set_xlabel('$N$', fontsize='14')
axs[1].set_ylabel(r'$\langle\bar{I}\rangle$', fontsize='14')
#axs[1, 1].set_title('$2^a$ Estimación, $Shots_1=2/5$')
axs[1].set_title('b)', loc='left', fontsize='18')

plt.savefig('graf,step2,STD24.pdf', bbox_inches='tight')

# %%
## Grafico de 2da etapa con STD

shots = 2/4
dims = np.array([4,8,16,32,64])
ens = 10**np.array([5,5.5,6,6.5,7])
alpha = 0.2

fig, axs = plt.subplots(1,2, figsize=(12,4))

axs[0].loglog(dims, 1-mmeanfid2_n5, 'ro-', label='$N=10^{5}$')
axs[0].loglog(dims, GM(dims,10**5,1), 'r--')
axs[0].fill_between(dims, (1-mmeanfid2_n5)-mstdfid2_n5, (1-mmeanfid2_n5)+mstdfid2_n5, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[0].loglog(dims, 1-mmeanfid2_n55, 'bo-', label='$N=10^{5.5}$')
axs[0].loglog(dims, GM(dims,10**5.5,1), 'b--')
axs[0].fill_between(dims, (1-mmeanfid2_n55)-mstdfid2_n55, (1-mmeanfid2_n55)+mstdfid2_n55, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[0].loglog(dims, 1-mmeanfid2_n6, 'go-', label='$N=10^{6}$')
axs[0].loglog(dims, GM(dims,10**6,1), 'g--')
axs[0].fill_between(dims, (1-mmeanfid2_n6)-mstdfid2_n6, (1-mmeanfid2_n6)+mstdfid2_n6, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[0].loglog(dims, 1-mmeanfid2_n65, 'yo-', label='$N=10^{6.5}$')
axs[0].loglog(dims, GM(dims,10**6.5, 1), 'y--')
axs[0].fill_between(dims, (1-mmeanfid2_n65)-mstdfid2_n65, (1-mmeanfid2_n65)+mstdfid2_n65, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[0].loglog(dims, 1-mmeanfid2_n7, 'co-', label='$N=10^{7}$')
axs[0].loglog(dims, GM(dims,10**7, 1), 'c--')
axs[0].fill_between(dims, (1-mmeanfid2_n7)-mstdfid2_n7, (1-mmeanfid2_n7)+mstdfid2_n7, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[0].legend()
axs[0].set_xlabel('Dimension', fontsize='14')
axs[0].set_ylabel('Infidelity', fontsize='14')
axs[0].set_title('$2^{nd}$ Estimation, $shots_1=1/2$', fontsize='18')
axs[0].set_title('a)', loc='left', fontsize='18')

###########################################################################

axs[1].loglog(ens, 1-mmeanfid2_d4, 'ro-', label='$d=4$')
axs[1].loglog(ens, GM(4,ens,1), 'r--')
axs[1].fill_between(ens, (1-mmeanfid2_d4)-mstdfid2_d4, (1-mmeanfid2_d4)+mstdfid2_d4, alpha=alpha, color='r')
#plt.loglog(dims, Ajuste(1.6,10**5,dims), 'r-')
axs[1].loglog(ens, 1-mmeanfid2_d8, 'bo-', label='$d=8$')
axs[1].loglog(ens, GM(8,ens,1), 'b--')
axs[1].fill_between(ens, (1-mmeanfid2_d8)-mstdfid2_d8, (1-mmeanfid2_d8)+mstdfid2_d8, alpha=alpha, color='b')
#plt.loglog(dims, Ajuste(1.7,10**5.5,dims), 'b-')
axs[1].loglog(ens, 1-mmeanfid2_d16, 'go-', label='$d=16$')
axs[1].loglog(ens, GM(16,ens,1), 'g--')
axs[1].fill_between(ens, (1-mmeanfid2_d16)-mstdfid2_d16, (1-mmeanfid2_d16)+mstdfid2_d16, alpha=alpha, color='g')
#plt.loglog(dims, Ajuste(1.47,10**6,dims),'g-')
axs[1].loglog(ens, 1-mmeanfid2_d32, 'yo-', label='$d=32$')
axs[1].loglog(ens, GM(32,ens, 1), 'y--')
axs[1].fill_between(ens, (1-mmeanfid2_d32)-mstdfid2_d32, (1-mmeanfid2_d32)+mstdfid2_d32, alpha=alpha, color='y')
#plt.loglog(dims, Ajuste(1.45,10**6.5,dims),'y-')
axs[1].loglog(ens, 1-mmeanfid2_d64, 'co-', label='$d=64$')
axs[1].loglog(ens, GM(64,ens, 1), 'c--')
axs[1].fill_between(ens, (1-mmeanfid2_d64)-mstdfid2_d64, (1-mmeanfid2_d64)+mstdfid2_d64, alpha=alpha, color='c')
#plt.loglog(dims, Ajuste(1.49,10**7,dims),'c-')

axs[1].legend()
axs[1].set_xlabel('N', fontsize='14')
axs[1].set_ylabel('$I$', fontsize='14')
#axs[1, 1].set_title('$2^a$ Estimación, $Shots_1=2/5$')
axs[1].set_title('b)', loc='left', fontsize='18')

plt.savefig('graf,2step,metodo_STD24.pdf', bbox_inches='tight')

# %% [markdown]
# # 5. Ajuste a la media de todos los estados

# %%
# Paso 1, fitear para 1 coef de posición infidelidad vs dimension

 ## AJUSTE POR DIMENSION

ensamble = 10**np.array([5,5.5,6,6.5,7])
shots = 1 # Fidelidad de la primera estimación 
x = np.log10(shots*ensamble+1)

#Ajuste
d=4
y = np.log10(1- mmeanfid2_d4)
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'd=',d,'$beta=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )

#Ajuste
d=8
y = np.log10(1- mmeanfid2_d8)
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'd=',d,'$beta=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )

#Ajuste
d=16
y = np.log10(1- mmeanfid2_d16)
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'd=',d,'$beta=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )

#Ajuste
d=32
y = np.log10(1- mmeanfid2_d32)
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'd=',d,'$beta=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )

#Ajuste
d=64
y = np.log10(1- mmeanfid2_d64)
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'd=',d,'$beta=', z[0][0],'Desviación estándar =', np.sqrt(np.diag(z[1]))[0] )


#Grafico
#plt.figure()
#plt.loglog(ensamble, 10**p(x), 'b-', label='Recta ajustada')
#plt.loglog(ensamble , 10**y , 'ro', label='Datos')
#plt.loglog(ensamble , (d-1)/10**x, 'm--', label='GM')
#plt.xlabel('Ensamble')
#plt.ylabel('Inf')
#plt.legend()
# Out:
# d= 4 $beta= -0.9919812108519699 Desviación estándar = 0.006034243466792305
# d= 8 $beta= -1.000753683304504 Desviación estándar = 0.00357002557148018
# d= 16 $beta= -1.0008109397218576 Desviación estándar = 0.0027410498795642883
# d= 32 $beta= -1.027378507058954 Desviación estándar = 0.01478182574441488
# d= 64 $beta= -1.214543044576664 Desviación estándar = 0.07574709334084603

# %%
np.mean([0.99,1.016,0.993,1.02,1.04])
# Out:
# 1.0118

# %%
# Paso 1, fitear para 1 coef de posición infidelidad vs ensamble


dims = 2**np.array([2,3,4,5,6])
x = np.log10(dims-1)

#Ajuste por ensamble
n = 10**5
y = np.log10(1-mmeanfid1_n5)  
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'n=',np.log10(n),'$gamma=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])

#Ajuste
n = 10**5.5
y = np.log10(1-mmeanfid1_n55)  
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'n=',np.log10(n),'$gamma=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])

#Ajuste
n = 10**6
y = np.log10(1-mmeanfid1_n6)  
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'n=',np.log10(n),'$gamma=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])

#Ajuste
n = 10**6.5
y = np.log10(1-mmeanfid1_n65)  
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'n=',np.log10(n),'$gamma=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])

#Ajuste
n = 10**7
y = np.log10(1-mmeanfid1_n7)  
z = np.polyfit(x,y,1, cov='True')
p = np.poly1d(z[0])

print(f'n=',np.log10(n),'$gamma=', z[0][0], 'Desviación estándar =', np.sqrt(np.diag(z[1]))[0])


#Grafico
#plt.figure()
#plt.loglog(dims, 10**p(x), 'b-', label='Recta ajustada')
#plt.loglog(dims , 10**y , 'ro', label='Datos')
#plt.loglog(dims , (dims-1)/(n+1), 'm--', label='GM')
#plt.xlabel('Dimensión')
#plt.ylabel('Inf')
#plt.legend()
# Out:
# n= 5.0 $gamma= 1.8876125981596874 Desviación estándar = 0.08288858738191444
# n= 5.5 $gamma= 1.8449295725371395 Desviación estándar = 0.08428136645493574
# n= 6.0 $gamma= 1.8373726502554066 Desviación estándar = 0.08433608966720484
# n= 6.5 $gamma= 1.8336040452848616 Desviación estándar = 0.05775450873661931
# n= 7.0 $gamma= 1.8109601663537194 Desviación estándar = 0.08060665973115397

# %%
np.mean([1.89,1.84,1.84,1.83,1.81])
# Out:
# 1.842

# %%
 ##Primero definir función a fitear
beta = 1
gamma = 1.84

ensamble = 10**np.array([5,5.5,6,6.5,7])
dims = 2**np.array([2,3,4,5,6])

print('beta=',beta,'gamma=',gamma)


 # AJUSTE POR ENSAMBLE fijo

print('Ajuste por ensamble')
def fun(d, alpha): #segunda estimación
    return np.log10(alpha) + gamma*np.log10((d-1)) - beta*np.log10(shots*n+1)

x = 1-mmeanfid1_n5
n = 10**5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_n55
n = 10**5.5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_n6
n = 10**6
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_n65
n = 10**6.5
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_n7
n = 10**7
popt , pcov = curve_fit( fun, dims, np.log10(x))
print('n=',np.log10(n),'$alpha$=',popt ,'error=', np.sqrt(pcov))


plt.loglog(dims, x ,'ro')
plt.loglog(dims, 10**fun(dims,popt), 'r--')

# AJUSTE POR DIMENSIÓN fija

print('Ajuste por dimensión')
def fun(n, alpha): #segunda estimación
    return np.log10(alpha) + gamma*np.log10((d-1)) - beta*np.log10(shots*n+1)

x = 1-mmeanfid1_d4
d = 4
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_d8
d = 8
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_d16
d = 16
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_d32
d = 32
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))

x = 1-mmeanfid1_d64
d = 64
popt , pcov = curve_fit( fun, ensamble, np.log10(x))
print('d=',d,'$alpha$=',popt ,'error=', np.sqrt(pcov))
# Out:
# beta= 1 gamma= 1.84
# Ajuste por ensamble
# n= 5.0 $alpha$= [1.36342813] error= [[0.11056486]]
# n= 5.5 $alpha$= [1.31175394] error= [[0.10272191]]
# n= 6.0 $alpha$= [1.33551551] error= [[0.10460785]]
# n= 6.5 $alpha$= [1.25303505] error= [[0.06733901]]
# n= 7.0 $alpha$= [1.28961847] error= [[0.09859637]]
# Ajuste por dimensión
# d= 4 $alpha$= [1.57272817] error= [[0.03662832]]
# d= 8 $alpha$= [1.12099284] error= [[0.01675732]]
# d= 16 $alpha$= [1.10775795] error= [[0.01134058]]
# d= 32 $alpha$= [1.32963277] error= [[0.03550682]]
# d= 64 $alpha$= [1.48636317] error= [[0.05844776]]
